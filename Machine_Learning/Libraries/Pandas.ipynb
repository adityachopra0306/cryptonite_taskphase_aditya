# %% [markdown]
# # Pandas
# Pandas is an essential Python library for data analysis and manipulation. It provides powerful data structures, Series and DataFrame, for handling and analyzing structured data, often sourced from CSV, Excel, SQL databases, or JSON files.
#
# ## Features:
# Allows easy data manipulation and cleaning.
# Provides robust data analysis tools.
# Supports handling missing data, grouping, and merging.

# %% [markdown]
# The Pandas library needs to be installed through pip, after which it can be imported to a Python Project

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series
#
# 1-Dimensional labeled array which can hold data of any type

# %% [markdown]
# ### Creating a Series

# %% [markdown]
# #### 1. From List

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s[3]
# Out:
# np.int64(40)

# %%
#Index arguments
indexargs = ['a','b','c','d','e']
s = pd.Series([10,20,30,40,50], indexargs, dtype='int32')
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int32

# %%
s['b']
# Out:
# np.int32(20)

# %% [markdown]
# #### 2. From Dictionary

# %%
cars = {'Tesla':10, 'Honda':15, 'Audi':20}
d = pd.Series(cars)
d
# Out:
# Tesla    10
# Honda    15
# Audi     20
# dtype: int64

# %% [markdown]
# ## DataFrames
#
# 2-Dimensional labeled array which can hold various columns of potentially different types

# %% [markdown]
# ### Creating a DataFrame

# %% [markdown]
# #### 1. From 2-dimensional array

# %%
dat = np.random.rand(4,3)
dat
# Out:
# array([[0.54431576, 0.94071811, 0.66130266],
#        [0.85805325, 0.97937772, 0.32507969],
#        [0.09511945, 0.49074733, 0.44924719],
#        [0.15055374, 0.96972209, 0.73998335]])

# %%
rows = ["A","B","C","D"]
cols = ["X","Y","Z"]

# %%
df = pd.DataFrame(dat, rows, cols)
df
# Out:
#           X         Y         Z
# A  0.544316  0.940718  0.661303
# B  0.858053  0.979378  0.325080
# C  0.095119  0.490747  0.449247
# D  0.150554  0.969722  0.739983

# %% [markdown]
# #### 2. From CSV File

# %%
CSVPATH = '../Resources/csvdata.csv'
csvdf = pd.read_csv(CSVPATH)
csvdf
# Out:
#    Name  Roll No  Marks
# 0     J        1     10
# 1     D        2     90
# 2     C        3     70
# 3     H        4     85
# 4     E        5     32
# 5     K        6     44
# 6     B        7     99
# 7     G        8    100
# 8     I        9     22
# 9     A       10     60
# 10    F       11     57

# %% [markdown]
# #### 3. From Excel File

# %%
EXCELPATH = '../Resources/exceldata.xlsx'
exceldf = pd.read_excel(EXCELPATH)
exceldf
# Out:
#    Name  Roll No  Marks
# 0     J        1     10
# 1     D        2     90
# 2     C        3     70
# 3     H        4     85
# 4     E        5     32
# 5     K        6     44
# 6     B        7     99
# 7     G        8    100
# 8     I        9     22
# 9     A       10     60
# 10    F       11     57

# %% [markdown]
# ### Accessing Data

# %% [markdown]
# #### 1. df.head(), df.tail()

# %%
#First 5 rows
exceldf.head()
# Out:
#   Name  Roll No  Marks
# 0    J        1     10
# 1    D        2     90
# 2    C        3     70
# 3    H        4     85
# 4    E        5     32

# %%
#Last 3 rows
exceldf.tail(3)
# Out:
#    Name  Roll No  Marks
# 8     I        9     22
# 9     A       10     60
# 10    F       11     57

# %% [markdown]
# #### 2. Direct Access

# %%
exceldf['Name']
# Out:
# 0     J
# 1     D
# 2     C
# 3     H
# 4     E
# 5     K
# 6     B
# 7     G
# 8     I
# 9     A
# 10    F
# Name: Name, dtype: object

# %%
exceldf[['Name','Marks']]
# Out:
#    Name  Marks
# 0     J     10
# 1     D     90
# 2     C     70
# 3     H     85
# 4     E     32
# 5     K     44
# 6     B     99
# 7     G    100
# 8     I     22
# 9     A     60
# 10    F     57

# %% [markdown]
# #### 3. df.loc[], df.iloc[]

# %%
exceldf.loc[0,['Name','Marks']]
# Out:
# Name      J
# Marks    10
# Name: 0, dtype: object

# %%
exceldf.loc[[0,1,2,3,4,5],:]
# Out:
#   Name  Roll No  Marks
# 0    J        1     10
# 1    D        2     90
# 2    C        3     70
# 3    H        4     85
# 4    E        5     32
# 5    K        6     44

# %%
exceldf.iloc[0,[1,2]]
# Out:
# Roll No     1
# Marks      10
# Name: 0, dtype: object

# %%
exceldf.iloc[:,2]
# Out:
# 0      10
# 1      90
# 2      70
# 3      85
# 4      32
# 5      44
# 6      99
# 7     100
# 8      22
# 9      60
# 10     57
# Name: Marks, dtype: int64

# %%
exceldf.iloc[3,:]
# Out:
# Name        H
# Roll No     4
# Marks      85
# Name: 3, dtype: object

# %% [markdown]
# ### Analysing Data

# %% [markdown]
# #### 1. Get DataFrame Information

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.shape
# Out:
# (4, 3)

# %%
df
# Out:
#           X         Y         Z
# A  0.544316  0.940718  0.661303
# B  0.858053  0.979378  0.325080
# C  0.095119  0.490747  0.449247
# D  0.150554  0.969722  0.739983

# %%
exceldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     11 non-null     object
#  1   Roll No  11 non-null     int64
#  2   Marks    11 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes

# %%
exceldf.dtypes
# Out:
# Name       object
# Roll No     int64
# Marks       int64
# dtype: object

# %% [markdown]
# #### 2. Statistical Analysis

# %%
exceldf.describe()
# Out:
#          Roll No       Marks
# count  11.000000   11.000000
# mean    6.000000   60.818182
# std     3.316625   31.195571
# min     1.000000   10.000000
# 25%     3.500000   38.000000
# 50%     6.000000   60.000000
# 75%     8.500000   87.500000
# max    11.000000  100.000000

# %%
exceldf['Name'].describe()
# Out:
# count     11
# unique    11
# top        J
# freq       1
# Name: Name, dtype: object

# %%
data = {
    'City': ['A', 'B', None, 'C', 'B', 'C'],
    'Category': ['X', 'X', 'Y', None, 'X', 'Y'],
    'Sales': [10, 20, 30, 40, None, 60]
}
df = pd.DataFrame(data)
df
# Out:
#    City Category  Sales
# 0     A        X   10.0
# 1     B        X   20.0
# 2  None        Y   30.0
# 3     C     None   40.0
# 4     B        X    NaN
# 5     C        Y   60.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      5 non-null      object
#  1   Category  5 non-null      object
#  2   Sales     5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df['Category'].value_counts()
# Out:
# Category
# X    3
# Y    2
# Name: count, dtype: int64

# %%
df['Category'].value_counts(ascending=True, dropna=False)
# Out:
# Category
# None    1
# Y       2
# X       3
# Name: count, dtype: int64

# %%
df['City'].value_counts(normalize=True)
# Out:
# City
# B    0.4
# C    0.4
# A    0.2
# Name: proportion, dtype: float64

# %%
df['City'].value_counts()['C']
# Out:
# np.int64(2)

# %%
df['City'].unique()
# Out:
# array(['A', 'B', None, 'C'], dtype=object)

# %%
df.groupby('City')['Sales'].agg(['sum','min','max','mean', 'count'])
# Out:
#         sum   min   max  mean  count
# City
# A      10.0  10.0  10.0  10.0      1
# B      20.0  20.0  20.0  20.0      1
# C     100.0  40.0  60.0  50.0      2

# %% [markdown]
# ### Manipulating Data

# %% [markdown]
# #### 1. Adding Columns

# %%
df
# Out:
#    City Category  Sales
# 0     A        X   10.0
# 1     B        X   20.0
# 2  None        Y   30.0
# 3     C     None   40.0
# 4     B        X    NaN
# 5     C        Y   60.0

# %%
profit = [2,10,2,5,None,10]
df["Profit"] = profit
df
# Out:
#    City Category  Sales  Profit
# 0     A        X   10.0     2.0
# 1     B        X   20.0    10.0
# 2  None        Y   30.0     2.0
# 3     C     None   40.0     5.0
# 4     B        X    NaN     NaN
# 5     C        Y   60.0    10.0

# %%
df["Ongoing"] = [True]*len(df)
df
# Out:
#    City Category  Sales  Profit  Ongoing
# 0     A        X   10.0     2.0     True
# 1     B        X   20.0    10.0     True
# 2  None        Y   30.0     2.0     True
# 3     C     None   40.0     5.0     True
# 4     B        X    NaN     NaN     True
# 5     C        Y   60.0    10.0     True

# %%
df.insert(1, "ID", [i for i in range(len(df))], False) #False- Don't allow Duplicates
df
# Out:
#    City  ID Category  Sales  Profit  Ongoing
# 0     A   0        X   10.0     2.0     True
# 1     B   1        X   20.0    10.0     True
# 2  None   2        Y   30.0     2.0     True
# 3     C   3     None   40.0     5.0     True
# 4     B   4        X    NaN     NaN     True
# 5     C   5        Y   60.0    10.0     True

# %%
df2 = df.assign(Quantity=[100*(np.random.randint(1,20)) for i in range(len(df))])
df2
# Out:
#    City  ID Category  Sales  Profit  Ongoing  Quantity
# 0     A   0        X   10.0     2.0     True       900
# 1     B   1        X   20.0    10.0     True       600
# 2  None   2        Y   30.0     2.0     True       600
# 3     C   3     None   40.0     5.0     True      1400
# 4     B   4        X    NaN     NaN     True      1900
# 5     C   5        Y   60.0    10.0     True       300

# %% [markdown]
# #### 2. Removing Rows and Columns

# %%
df2
# Out:
#    City  ID Category  Sales  Profit  Ongoing  Quantity
# 0     A   0        X   10.0     2.0     True       900
# 1     B   1        X   20.0    10.0     True       600
# 2  None   2        Y   30.0     2.0     True       600
# 3     C   3     None   40.0     5.0     True      1400
# 4     B   4        X    NaN     NaN     True      1900
# 5     C   5        Y   60.0    10.0     True       300

# %%
df2 = df2.drop('City',axis=1)
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   0        X   10.0     2.0     True       900
# 1   1        X   20.0    10.0     True       600
# 2   2        Y   30.0     2.0     True       600
# 3   3     None   40.0     5.0     True      1400
# 4   4        X    NaN     NaN     True      1900
# 5   5        Y   60.0    10.0     True       300

# %%
df2 = df2.loc[0:6:2,['ID','Category','Sales']]
df2
# Out:
#    ID Category  Sales
# 0   0        X   10.0
# 2   2        Y   30.0
# 4   4        X    NaN

# %%
df2 = df.assign(Quantity=[100*(np.random.randint(1,20)) for i in range(len(df))])
df2
# Out:
#    City  ID Category  Sales  Profit  Ongoing  Quantity
# 0     A   0        X   10.0     2.0     True       300
# 1     B   1        X   20.0    10.0     True      1900
# 2  None   2        Y   30.0     2.0     True      1000
# 3     C   3     None   40.0     5.0     True       300
# 4     B   4        X    NaN     NaN     True       700
# 5     C   5        Y   60.0    10.0     True      1300

# %%
df2.drop('City', axis=1, inplace=True)
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   0        X   10.0     2.0     True       300
# 1   1        X   20.0    10.0     True      1900
# 2   2        Y   30.0     2.0     True      1000
# 3   3     None   40.0     5.0     True       300
# 4   4        X    NaN     NaN     True       700
# 5   5        Y   60.0    10.0     True      1300

# %%
df2.drop(0,inplace=True)
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 1   1        X   20.0    10.0     True      1900
# 2   2        Y   30.0     2.0     True      1000
# 3   3     None   40.0     5.0     True       300
# 4   4        X    NaN     NaN     True       700
# 5   5        Y   60.0    10.0     True      1300

# %% [markdown]
# #### 3. Adding Rows

# %%
newdf = pd.DataFrame({
    "ID":[6,7],
    "Category":['Y','X'],
    "Sales": [15, 5],
    "Profit": [20, 50],
    "Ongoing": [True, False],
    "Quantity": [200, 20]
})
df2 = pd.concat([df2, newdf],ignore_index=True)
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 2   3     None   40.0     5.0     True       300
# 3   4        X    NaN     NaN     True       700
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20

# %%
df2.loc[len(df2)] = [len(df2)+1,'Y',10,2,False,500]
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 2   3     None   40.0     5.0     True       300
# 3   4        X    NaN     NaN     True       700
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %% [markdown]
# #### 4. Set Index

# %%
df.drop(0,axis=0,inplace=True)
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df
# Out:
#    City  ID Category  Sales  Profit  Ongoing
# 0     B   1        X   20.0    10.0     True
# 1  None   2        Y   30.0     2.0     True
# 2     C   3     None   40.0     5.0     True
# 3     B   4        X    NaN     NaN     True
# 4     C   5        Y   60.0    10.0     True

# %%
df.set_index("ID", inplace=True)
df
# Out:
#     City Category  Sales  Profit  Ongoing
# ID
# 1      B        X   20.0    10.0     True
# 2   None        Y   30.0     2.0     True
# 3      C     None   40.0     5.0     True
# 4      B        X    NaN     NaN     True
# 5      C        Y   60.0    10.0     True

# %% [markdown]
# ### Conditional Selection

# %%
 df2 == 10
# Out:
#       ID  Category  Sales  Profit  Ongoing  Quantity
# 0  False     False  False    True    False     False
# 1  False     False  False   False    False     False
# 2  False     False  False   False    False     False
# 3  False     False  False   False    False     False
# 4  False     False  False    True    False     False
# 5  False     False  False   False    False     False
# 6  False     False  False   False    False     False
# 7  False     False   True   False    False     False

# %%
df2[df2==10]
# Out:
#    ID Category  Sales  Profit Ongoing  Quantity
# 0 NaN      NaN    NaN    10.0     NaN       NaN
# 1 NaN      NaN    NaN     NaN     NaN       NaN
# 2 NaN      NaN    NaN     NaN     NaN       NaN
# 3 NaN      NaN    NaN     NaN     NaN       NaN
# 4 NaN      NaN    NaN    10.0     NaN       NaN
# 5 NaN      NaN    NaN     NaN     NaN       NaN
# 6 NaN      NaN    NaN     NaN     NaN       NaN
# 7 NaN      NaN   10.0     NaN     NaN       NaN

# %%
df2[df2==10]['Profit']
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4    10.0
# 5     NaN
# 6     NaN
# 7     NaN
# Name: Profit, dtype: float64

# %%
df2[(df2['ID']%2==0) & (df2['Profit']!=10)]
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 1   2        Y   30.0     2.0     True      1000
# 3   4        X    NaN     NaN     True       700
# 5   6        Y   15.0    20.0     True       200
# 7   8        Y   10.0     2.0    False       500

# %%
df2[(df2['ID']%2!=0) | (df2['Profit']==10)]
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 2   3     None   40.0     5.0     True       300
# 4   5        Y   60.0    10.0     True      1300
# 6   7        X    5.0    50.0    False        20

# %% [markdown]
# ### Handling Missing Data

# %%
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 2   3     None   40.0     5.0     True       300
# 3   4        X    NaN     NaN     True       700
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %%
df2.isnull()
# Out:
#       ID  Category  Sales  Profit  Ongoing  Quantity
# 0  False     False  False   False    False     False
# 1  False     False  False   False    False     False
# 2  False      True  False   False    False     False
# 3  False     False   True    True    False     False
# 4  False     False  False   False    False     False
# 5  False     False  False   False    False     False
# 6  False     False  False   False    False     False
# 7  False     False  False   False    False     False

# %%
df2_nonullrow = df2.dropna(axis=0)
df2_nonullrow
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %%
df2_nonullcol = df2.dropna(axis=1)
df2_nonullcol
# Out:
#    ID  Ongoing  Quantity
# 0   1     True      1900
# 1   2     True      1000
# 2   3     True       300
# 3   4     True       700
# 4   5     True      1300
# 5   6     True       200
# 6   7    False        20
# 7   8    False       500

# %%
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 2   3     None   40.0     5.0     True       300
# 3   4        X    NaN     NaN     True       700
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %%
df2_fillednull = df2.fillna('NA')
df2_fillednull
# Out:
#    ID Category Sales Profit  Ongoing  Quantity
# 0   1        X  20.0   10.0     True      1900
# 1   2        Y  30.0    2.0     True      1000
# 2   3       NA  40.0    5.0     True       300
# 3   4        X    NA     NA     True       700
# 4   5        Y  60.0   10.0     True      1300
# 5   6        Y  15.0   20.0     True       200
# 6   7        X   5.0   50.0    False        20
# 7   8        Y  10.0    2.0    False       500

# %%
df2_fillednull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        8 non-null      int64
#  1   Category  8 non-null      object
#  2   Sales     8 non-null      object
#  3   Profit    8 non-null      object
#  4   Ongoing   8 non-null      bool
#  5   Quantity  8 non-null      int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 392.0+ bytes

# %% [markdown]
# ### Functions

# %%
def tentimes(x):
    return x*10

# %%
df2_nonullrow
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %%
df2_nonullrow['Quantity'].apply(tentimes)
# Out:
# 0    19000
# 1    10000
# 4    13000
# 5     2000
# 6      200
# 7     5000
# Name: Quantity, dtype: int64

# %%
df2_nonullrow['Profit'].apply(lambda x: x**2)
# Out:
# 0     100.0
# 1       4.0
# 4     100.0
# 5     400.0
# 6    2500.0
# 7       4.0
# Name: Profit, dtype: float64

# %%
df2_nonullrow[['Sales','Profit']].apply(tentimes)
# Out:
#    Sales  Profit
# 0  200.0   100.0
# 1  300.0    20.0
# 4  600.0   100.0
# 5  150.0   200.0
# 6   50.0   500.0
# 7  100.0    20.0

# %% [markdown]
# ### Sorting and Ordering

# %%
df2
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 1   2        Y   30.0     2.0     True      1000
# 2   3     None   40.0     5.0     True       300
# 3   4        X    NaN     NaN     True       700
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 6   7        X    5.0    50.0    False        20
# 7   8        Y   10.0     2.0    False       500

# %%
df2.sort_values('Sales', ascending=False, inplace=False)
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 4   5        Y   60.0    10.0     True      1300
# 2   3     None   40.0     5.0     True       300
# 1   2        Y   30.0     2.0     True      1000
# 0   1        X   20.0    10.0     True      1900
# 5   6        Y   15.0    20.0     True       200
# 7   8        Y   10.0     2.0    False       500
# 6   7        X    5.0    50.0    False        20
# 3   4        X    NaN     NaN     True       700

# %%
df2.sort_values('Category')
# Out:
#    ID Category  Sales  Profit  Ongoing  Quantity
# 0   1        X   20.0    10.0     True      1900
# 3   4        X    NaN     NaN     True       700
# 6   7        X    5.0    50.0    False        20
# 1   2        Y   30.0     2.0     True      1000
# 4   5        Y   60.0    10.0     True      1300
# 5   6        Y   15.0    20.0     True       200
# 7   8        Y   10.0     2.0    False       500
# 2   3     None   40.0     5.0     True       300
